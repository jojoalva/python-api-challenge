# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 597

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&units=metric&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
    
    
        #Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']
    

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | puerto natales
# Processing Record 2 of Set 1 | adamstown
# Processing Record 3 of Set 1 | swakopmund
# Processing Record 4 of Set 1 | hasaki
# Processing Record 5 of Set 1 | alofi
# Processing Record 6 of Set 1 | hithadhoo
# Processing Record 7 of Set 1 | ushuaia
# Processing Record 8 of Set 1 | grytviken
# Processing Record 9 of Set 1 | fale old settlement
# Processing Record 10 of Set 1 | saint-philippe
# Processing Record 11 of Set 1 | nuuk
# Processing Record 12 of Set 1 | lihue
# Processing Record 13 of Set 1 | port-aux-francais
# Processing Record 14 of Set 1 | stornoway
# Processing Record 15 of Set 1 | anar darah
# Processing Record 16 of Set 1 | xining
# Processing Record 17 of Set 1 | nikolayevsk-on-amure
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | saipan
# Processing Record 20 of Set 1 | la'ie
# Processing Record 21 of Set 1 | yigo village
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | hilo
# Processing Record 24 of Set 1 | al khums
# Processing Record 25 of Set 1 | al jawf
# Processing Record 26 of Set 1 | bethel
# Processing Record 27 of Set 1 | kirakira
# Processing Record 28 of Set 1 | taiohae
# City not found. Skipping...
# Processing Record 29 of Set 1 | bredasdorp
# Processing Record 30 of Set 1 | yangor
# City not found. Skipping...
# Processing Record 31 of Set 1 | ilulissat
# Processing Record 32 of Set 1 | qaqortoq
# Processing Record 33 of Set 1 | mahajanga
# Processing Record 34 of Set 1 | fonadhoo
# City not found. Skipping...
# Processing Record 35 of Set 1 | san jose de lourdes
# City not found. Skipping...
# Processing Record 36 of Set 1 | lethem
# Processing Record 37 of Set 1 | puerto santa
# Processing Record 38 of Set 1 | yermentau
# Processing Record 39 of Set 1 | makaha
# Processing Record 40 of Set 1 | port mathurin
# Processing Record 41 of Set 1 | i-n-salah
# Processing Record 42 of Set 1 | melfort
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | puerto san carlos
# City not found. Skipping...
# Processing Record 45 of Set 1 | brewer
# Processing Record 46 of Set 1 | waitangi
# Processing Record 47 of Set 1 | margaret river
# Processing Record 48 of Set 1 | angaur state
# Processing Record 49 of Set 1 | martuk
# Processing Record 50 of Set 1 | ondjiva
# Processing Record 0 of Set 2 | muang phonsavan
# Processing Record 1 of Set 2 | lima
# Processing Record 2 of Set 2 | revda
# Processing Record 3 of Set 2 | edinburgh of the seven seas
# Processing Record 4 of Set 2 | magadan
# Processing Record 5 of Set 2 | monticello
# Processing Record 6 of Set 2 | buchanan
# Processing Record 7 of Set 2 | fuerte olimpo
# Processing Record 8 of Set 2 | aksu
# Processing Record 9 of Set 2 | olonkinbyen
# Processing Record 10 of Set 2 | san pedro pochutla
# Processing Record 11 of Set 2 | tiksi
# Processing Record 12 of Set 2 | puerto baquerizo moreno
# Processing Record 13 of Set 2 | udachny
# Processing Record 14 of Set 2 | humaita
# Processing Record 15 of Set 2 | hanceville
# Processing Record 16 of Set 2 | nouadhibou
# Processing Record 17 of Set 2 | al 'alamayn
# City not found. Skipping...
# Processing Record 18 of Set 2 | tazovsky
# Processing Record 19 of Set 2 | iqaluit
# Processing Record 20 of Set 2 | hermanus
# Processing Record 21 of Set 2 | howard springs
# Processing Record 22 of Set 2 | dalandzadgad
# Processing Record 23 of Set 2 | charters towers
# Processing Record 24 of Set 2 | piti village
# Processing Record 25 of Set 2 | tofol
# Processing Record 26 of Set 2 | susuman
# Processing Record 27 of Set 2 | awjilah
# Processing Record 28 of Set 2 | papatowai
# Processing Record 29 of Set 2 | alice springs
# Processing Record 30 of Set 2 | keflavik
# Processing Record 31 of Set 2 | egilsstadir
# Processing Record 32 of Set 2 | bamboo flat
# Processing Record 33 of Set 2 | labrador city
# Processing Record 34 of Set 2 | pisco
# Processing Record 35 of Set 2 | talnakh
# Processing Record 36 of Set 2 | kingscliff
# Processing Record 37 of Set 2 | 'ohonua
# City not found. Skipping...
# Processing Record 38 of Set 2 | maridi
# Processing Record 39 of Set 2 | flying fish cove
# Processing Record 40 of Set 2 | walvis bay
# Processing Record 41 of Set 2 | coahuayana de hidalgo
# Processing Record 42 of Set 2 | porto novo
# Processing Record 43 of Set 2 | zambezi
# Processing Record 44 of Set 2 | yellowknife
# Processing Record 45 of Set 2 | salor
# Processing Record 46 of Set 2 | stanley
# Processing Record 47 of Set 2 | fortuna
# Processing Record 48 of Set 2 | neiafu
# Processing Record 49 of Set 2 | khuzdar
# Processing Record 0 of Set 3 | vorgashor
# Processing Record 1 of Set 3 | sisimiut
# Processing Record 2 of Set 3 | fort st. john
# Processing Record 3 of Set 3 | blackmans bay
# Processing Record 4 of Set 3 | whitehorse
# Processing Record 5 of Set 3 | mawlamyinegyunn
# Processing Record 6 of Set 3 | jiangyou
# Processing Record 7 of Set 3 | hawaiian paradise park
# Processing Record 8 of Set 3 | kokopo
# Processing Record 9 of Set 3 | nemuro
# Processing Record 10 of Set 3 | mogadishu
# Processing Record 11 of Set 3 | mount gambier
# Processing Record 12 of Set 3 | thompson
# Processing Record 13 of Set 3 | twon-brass
# Processing Record 14 of Set 3 | berbera
# Processing Record 15 of Set 3 | emerald
# Processing Record 16 of Set 3 | isafjordur
# Processing Record 17 of Set 3 | sonsorol village
# City not found. Skipping...
# Processing Record 18 of Set 3 | robore
# Processing Record 19 of Set 3 | mata-utu
# Processing Record 20 of Set 3 | sinabang
# Processing Record 21 of Set 3 | portrush
# Processing Record 22 of Set 3 | helena valley southeast
# Processing Record 23 of Set 3 | dampit
# Processing Record 24 of Set 3 | ambodifotatra
# Processing Record 25 of Set 3 | thinadhoo
# Processing Record 26 of Set 3 | luau
# Processing Record 27 of Set 3 | sabha
# Processing Record 28 of Set 3 | puerto deseado
# Processing Record 29 of Set 3 | hadibu
# Processing Record 30 of Set 3 | jimo
# Processing Record 31 of Set 3 | fort mcmurray
# Processing Record 32 of Set 3 | birao
# Processing Record 33 of Set 3 | bilibino
# Processing Record 34 of Set 3 | lompoc
# Processing Record 35 of Set 3 | newcastle
# Processing Record 36 of Set 3 | klyuchi
# Processing Record 37 of Set 3 | habiganj
# Processing Record 38 of Set 3 | ust'-ilimsk
# Processing Record 39 of Set 3 | howrah
# Processing Record 40 of Set 3 | lazaro cardenas
# Processing Record 41 of Set 3 | tangalle
# Processing Record 42 of Set 3 | port saint john's
# Processing Record 43 of Set 3 | bairnsdale
# Processing Record 44 of Set 3 | carnarvon
# Processing Record 45 of Set 3 | banda aceh
# Processing Record 46 of Set 3 | utrik
# Processing Record 47 of Set 3 | longyearbyen
# Processing Record 48 of Set 3 | invercargill
# Processing Record 49 of Set 3 | portland
# Processing Record 0 of Set 4 | ulety
# Processing Record 1 of Set 4 | burabay
# Processing Record 2 of Set 4 | corinto
# Processing Record 3 of Set 4 | djibo
# Processing Record 4 of Set 4 | rongelap
# Processing Record 5 of Set 4 | ribeira grande
# Processing Record 6 of Set 4 | pandatarai
# City not found. Skipping...
# Processing Record 7 of Set 4 | west island
# Processing Record 8 of Set 4 | kununurra
# Processing Record 9 of Set 4 | burang
# Processing Record 10 of Set 4 | kulia village
# City not found. Skipping...
# Processing Record 11 of Set 4 | uturoa
# Processing Record 12 of Set 4 | cabo san lucas
# Processing Record 13 of Set 4 | anadyr
# Processing Record 14 of Set 4 | sakaiminato
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | tiznit
# Processing Record 17 of Set 4 | sovetskiy
# Processing Record 18 of Set 4 | san juan
# Processing Record 19 of Set 4 | hakui
# Processing Record 20 of Set 4 | nova sintra
# Processing Record 21 of Set 4 | san andres
# Processing Record 22 of Set 4 | hervey bay
# Processing Record 23 of Set 4 | boguchany
# Processing Record 24 of Set 4 | callao
# Processing Record 25 of Set 4 | arjona
# Processing Record 26 of Set 4 | forster
# Processing Record 27 of Set 4 | enewetak
# Processing Record 28 of Set 4 | luderitz
# Processing Record 29 of Set 4 | naze
# Processing Record 30 of Set 4 | ovalle
# Processing Record 31 of Set 4 | troitsk
# Processing Record 32 of Set 4 | malango
# Processing Record 33 of Set 4 | mount isa
# Processing Record 34 of Set 4 | haiku-pauwela
# Processing Record 35 of Set 4 | avarua
# Processing Record 36 of Set 4 | ust-nera
# Processing Record 37 of Set 4 | sur
# Processing Record 38 of Set 4 | ranchettes
# Processing Record 39 of Set 4 | gafsa
# Processing Record 40 of Set 4 | vila franca do campo
# Processing Record 41 of Set 4 | zunyi
# Processing Record 42 of Set 4 | kodiak
# Processing Record 43 of Set 4 | fisterra
# Processing Record 44 of Set 4 | tadine
# Processing Record 45 of Set 4 | badger
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | dunhua
# Processing Record 48 of Set 4 | pacific grove
# Processing Record 49 of Set 4 | daru
# Processing Record 0 of Set 5 | tazacorte
# Processing Record 1 of Set 5 | lebu
# Processing Record 2 of Set 5 | horta
# Processing Record 3 of Set 5 | mwene-ditu
# Processing Record 4 of Set 5 | jieshi
# Processing Record 5 of Set 5 | letlhakane
# Processing Record 6 of Set 5 | katsuren-haebaru
# Processing Record 7 of Set 5 | patacamaya
# Processing Record 8 of Set 5 | simpang
# Processing Record 9 of Set 5 | inari
# Processing Record 10 of Set 5 | rakops
# Processing Record 11 of Set 5 | palikir - national government center
# Processing Record 12 of Set 5 | cozumel
# Processing Record 13 of Set 5 | kara suu
# Processing Record 14 of Set 5 | quellon
# Processing Record 15 of Set 5 | lokken
# City not found. Skipping...
# Processing Record 16 of Set 5 | vorkuta
# Processing Record 17 of Set 5 | madang
# Processing Record 18 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 19 of Set 5 | bodo
# Processing Record 20 of Set 5 | kupang
# Processing Record 21 of Set 5 | balaklava
# Processing Record 22 of Set 5 | meulaboh
# Processing Record 23 of Set 5 | chibougamau
# Processing Record 24 of Set 5 | wijk bij duurstede
# Processing Record 25 of Set 5 | malaunay
# Processing Record 26 of Set 5 | kailua-kona
# Processing Record 27 of Set 5 | rio grande
# Processing Record 28 of Set 5 | dharur
# Processing Record 29 of Set 5 | miles city
# Processing Record 30 of Set 5 | carutapera
# Processing Record 31 of Set 5 | atafu village
# Processing Record 32 of Set 5 | sungai penuh
# Processing Record 33 of Set 5 | moia
# Processing Record 34 of Set 5 | port elizabeth
# Processing Record 35 of Set 5 | weno
# Processing Record 36 of Set 5 | ingeniero guillermo n. juarez
# Processing Record 37 of Set 5 | la libertad
# Processing Record 38 of Set 5 | tsiombe
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | chiang khong
# Processing Record 41 of Set 5 | anabar
# City not found. Skipping...
# Processing Record 42 of Set 5 | magnanville
# Processing Record 43 of Set 5 | juegang
# Processing Record 44 of Set 5 | ivanivka
# Processing Record 45 of Set 5 | bikenibeu village
# Processing Record 46 of Set 5 | vilyuchinsk
# Processing Record 47 of Set 5 | champerico
# Processing Record 48 of Set 5 | pemba
# Processing Record 49 of Set 5 | illizi
# Processing Record 0 of Set 6 | fuglafjordur
# Processing Record 1 of Set 6 | la ronge
# Processing Record 2 of Set 6 | jamestown
# Processing Record 3 of Set 6 | pandan
# Processing Record 4 of Set 6 | smidovich
# Processing Record 5 of Set 6 | lata
# Processing Record 6 of Set 6 | port lincoln
# Processing Record 7 of Set 6 | prince rupert
# Processing Record 8 of Set 6 | mesquite
# Processing Record 9 of Set 6 | el-tor
# Processing Record 10 of Set 6 | am timan
# Processing Record 11 of Set 6 | pemangkat
# Processing Record 12 of Set 6 | kiunga
# Processing Record 13 of Set 6 | reshetikha
# Processing Record 14 of Set 6 | red deer
# Processing Record 15 of Set 6 | tippi
# Processing Record 16 of Set 6 | penza
# Processing Record 17 of Set 6 | aroma
# Processing Record 18 of Set 6 | aasiaat
# Processing Record 19 of Set 6 | coquimbo
# Processing Record 20 of Set 6 | aginskoye
# Processing Record 21 of Set 6 | la passe
# Processing Record 22 of Set 6 | bentiu
# Processing Record 23 of Set 6 | oranjemund
# Processing Record 24 of Set 6 | kill devil hills
# Processing Record 25 of Set 6 | st. john's
# Processing Record 26 of Set 6 | arkhangel'sk
# Processing Record 27 of Set 6 | soron
# Processing Record 28 of Set 6 | afaahiti
# Processing Record 29 of Set 6 | crane
# Processing Record 30 of Set 6 | aykhal
# Processing Record 31 of Set 6 | constantia
# Processing Record 32 of Set 6 | amahai
# Processing Record 33 of Set 6 | port alfred
# Processing Record 34 of Set 6 | brigantine
# Processing Record 35 of Set 6 | lumberton
# Processing Record 36 of Set 6 | am djarass
# City not found. Skipping...
# Processing Record 37 of Set 6 | college
# Processing Record 38 of Set 6 | belel
# Processing Record 39 of Set 6 | vadso
# Processing Record 40 of Set 6 | irymple
# Processing Record 41 of Set 6 | santa cruz
# Processing Record 42 of Set 6 | temerluh
# Processing Record 43 of Set 6 | nchelenge
# Processing Record 44 of Set 6 | ta`u
# Processing Record 45 of Set 6 | wanning
# Processing Record 46 of Set 6 | castel volturno
# Processing Record 47 of Set 6 | ola
# Processing Record 48 of Set 6 | paracuru
# Processing Record 49 of Set 6 | trairi
# Processing Record 0 of Set 7 | paranhos
# Processing Record 1 of Set 7 | ketchikan
# Processing Record 2 of Set 7 | nagqu
# Processing Record 3 of Set 7 | tobi village
# City not found. Skipping...
# Processing Record 4 of Set 7 | kutum
# Processing Record 5 of Set 7 | vrnjacka banja
# Processing Record 6 of Set 7 | lensk
# Processing Record 7 of Set 7 | dongola
# Processing Record 8 of Set 7 | san patricio
# Processing Record 9 of Set 7 | nar'yan-mar
# Processing Record 10 of Set 7 | labytnangi
# Processing Record 11 of Set 7 | oguzeli
# Processing Record 12 of Set 7 | saint-louis du nord
# Processing Record 13 of Set 7 | vila velha
# Processing Record 14 of Set 7 | salalah
# Processing Record 15 of Set 7 | toliara
# Processing Record 16 of Set 7 | biloela
# Processing Record 17 of Set 7 | kananga
# Processing Record 18 of Set 7 | arraial do cabo
# Processing Record 19 of Set 7 | klaksvik
# Processing Record 20 of Set 7 | lubang
# Processing Record 21 of Set 7 | ujae
# Processing Record 22 of Set 7 | geraldton
# Processing Record 23 of Set 7 | ponta pora
# Processing Record 24 of Set 7 | mount pearl
# Processing Record 25 of Set 7 | dudinka
# Processing Record 26 of Set 7 | namibe
# Processing Record 27 of Set 7 | villamontes
# Processing Record 28 of Set 7 | sao vicente
# Processing Record 29 of Set 7 | hayma'
# City not found. Skipping...
# Processing Record 30 of Set 7 | nuku'alofa
# Processing Record 31 of Set 7 | morehead city
# Processing Record 32 of Set 7 | ourilandia do norte
# City not found. Skipping...
# Processing Record 33 of Set 7 | khandyga
# Processing Record 34 of Set 7 | manacapuru
# Processing Record 35 of Set 7 | remire-montjoly
# Processing Record 36 of Set 7 | tura
# Processing Record 37 of Set 7 | impfondo
# Processing Record 38 of Set 7 | eydhafushi
# Processing Record 39 of Set 7 | ciudad del carmen
# Processing Record 40 of Set 7 | zakynthos
# Processing Record 41 of Set 7 | umm kaddadah
# Processing Record 42 of Set 7 | san rafael
# Processing Record 43 of Set 7 | novo aripuana
# Processing Record 44 of Set 7 | kristiansund
# Processing Record 45 of Set 7 | saudarkrokur
# Processing Record 46 of Set 7 | hobyo
# Processing Record 47 of Set 7 | moussoro
# Processing Record 48 of Set 7 | whakatane
# Processing Record 49 of Set 7 | nkurenkuru
# City not found. Skipping...
# Processing Record 0 of Set 8 | dingras
# Processing Record 1 of Set 8 | schweizer-reneke
# Processing Record 2 of Set 8 | mahina
# Processing Record 3 of Set 8 | basco
# Processing Record 4 of Set 8 | nastola
# Processing Record 5 of Set 8 | suva
# Processing Record 6 of Set 8 | bucerias
# Processing Record 7 of Set 8 | beidao
# Processing Record 8 of Set 8 | mil'kovo
# Processing Record 9 of Set 8 | pyapon
# Processing Record 10 of Set 8 | rikaze
# Processing Record 11 of Set 8 | tuy hoa
# Processing Record 12 of Set 8 | lively
# Processing Record 13 of Set 8 | belyye berega
# Processing Record 14 of Set 8 | touros
# Processing Record 15 of Set 8 | el bauga
# Processing Record 16 of Set 8 | ulsteinvik
# Processing Record 17 of Set 8 | tobelo
# Processing Record 18 of Set 8 | siwa oasis
# Processing Record 19 of Set 8 | fonte boa
# Processing Record 20 of Set 8 | beira
# Processing Record 21 of Set 8 | tanrake village
# City not found. Skipping...
# Processing Record 22 of Set 8 | natal
# Processing Record 23 of Set 8 | mabaruma
# Processing Record 24 of Set 8 | tot'ma
# Processing Record 25 of Set 8 | taro
# Processing Record 26 of Set 8 | al badari
# Processing Record 27 of Set 8 | contai
# Processing Record 28 of Set 8 | terrace
# Processing Record 29 of Set 8 | kingston
# Processing Record 30 of Set 8 | pindushi
# Processing Record 31 of Set 8 | gazojak
# Processing Record 32 of Set 8 | lawrenceville
# Processing Record 33 of Set 8 | usogorsk
# Processing Record 34 of Set 8 | punta arenas
# Processing Record 35 of Set 8 | midoun
# Processing Record 36 of Set 8 | newman
# Processing Record 37 of Set 8 | revelstoke
# Processing Record 38 of Set 8 | dawei
# Processing Record 39 of Set 8 | governor's harbour
# City not found. Skipping...
# Processing Record 40 of Set 8 | severo-yeniseyskiy
# Processing Record 41 of Set 8 | jamalpur
# Processing Record 42 of Set 8 | cairns city
# City not found. Skipping...
# Processing Record 43 of Set 8 | okha
# Processing Record 44 of Set 8 | tandil
# Processing Record 45 of Set 8 | tongouson
# Processing Record 46 of Set 8 | bel ombre
# Processing Record 47 of Set 8 | buala
# Processing Record 48 of Set 8 | la jagua de ibirico
# Processing Record 49 of Set 8 | baishishan
# Processing Record 0 of Set 9 | khash
# Processing Record 1 of Set 9 | port pirie
# Processing Record 2 of Set 9 | nasir
# Processing Record 3 of Set 9 | ladario
# Processing Record 4 of Set 9 | grantsville
# Processing Record 5 of Set 9 | wailua homesteads
# Processing Record 6 of Set 9 | elko
# Processing Record 7 of Set 9 | yurimaguas
# Processing Record 8 of Set 9 | nizhneangarsk
# Processing Record 9 of Set 9 | tsagan aman
# Processing Record 10 of Set 9 | gaalkacyo
# Processing Record 11 of Set 9 | weihai
# Processing Record 12 of Set 9 | yulin
# Processing Record 13 of Set 9 | jaisalmer
# Processing Record 14 of Set 9 | brisas de zicatela
# Processing Record 15 of Set 9 | benjamin constant
# Processing Record 16 of Set 9 | weirton
# Processing Record 17 of Set 9 | merizo village
# Processing Record 18 of Set 9 | cromwell
# Processing Record 19 of Set 9 | alvaraes
# Processing Record 20 of Set 9 | aral
# Processing Record 21 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 22 of Set 9 | rainbow city
# Processing Record 23 of Set 9 | ankang
# Processing Record 24 of Set 9 | codrington
# Processing Record 25 of Set 9 | gebeit
# Processing Record 26 of Set 9 | san luis de la loma
# Processing Record 27 of Set 9 | chonchi
# Processing Record 28 of Set 9 | marion
# Processing Record 29 of Set 9 | bohlen
# Processing Record 30 of Set 9 | shangri-la
# City not found. Skipping...
# Processing Record 31 of Set 9 | hugo
# Processing Record 32 of Set 9 | humberto de campos
# Processing Record 33 of Set 9 | yangshuo
# Processing Record 34 of Set 9 | tejen
# Processing Record 35 of Set 9 | freetown
# Processing Record 36 of Set 9 | hoxtolgay
# City not found. Skipping...
# Processing Record 37 of Set 9 | minas de marcona
# Processing Record 38 of Set 9 | tver
# Processing Record 39 of Set 9 | ghat
# Processing Record 40 of Set 9 | yagry
# City not found. Skipping...
# Processing Record 41 of Set 9 | papao
# Processing Record 42 of Set 9 | laguna beach
# Processing Record 43 of Set 9 | trinidad
# Processing Record 44 of Set 9 | mulanje
# Processing Record 45 of Set 9 | madalena
# Processing Record 46 of Set 9 | kongoussi
# Processing Record 47 of Set 9 | cihuatlan
# Processing Record 48 of Set 9 | washim
# Processing Record 49 of Set 9 | pemalang
# Processing Record 0 of Set 10 | harstad
# Processing Record 1 of Set 10 | indramayu
# Processing Record 2 of Set 10 | salinopolis
# Processing Record 3 of Set 10 | christchurch
# Processing Record 4 of Set 10 | mahibadhoo
# Processing Record 5 of Set 10 | bichura
# Processing Record 6 of Set 10 | petatlan
# Processing Record 7 of Set 10 | morant bay
# Processing Record 8 of Set 10 | djibouti
# Processing Record 9 of Set 10 | dubbo
# Processing Record 10 of Set 10 | matoury
# Processing Record 11 of Set 10 | mukah
# City not found. Skipping...
# Processing Record 12 of Set 10 | peace river
# Processing Record 13 of Set 10 | changtu
# Processing Record 14 of Set 10 | la gi
# Processing Record 15 of Set 10 | yerofey pavlovich
# Processing Record 16 of Set 10 | bardaskan
# City not found. Skipping...
# Processing Record 17 of Set 10 | bikin
# Processing Record 18 of Set 10 | rabigh
# Processing Record 19 of Set 10 | ouadda
# Processing Record 20 of Set 10 | pingyi
# Processing Record 21 of Set 10 | cidreira
# Processing Record 22 of Set 10 | eyl
# Processing Record 23 of Set 10 | lorengau
# Processing Record 24 of Set 10 | high rock
# Processing Record 25 of Set 10 | cable beach
# City not found. Skipping...
# Processing Record 26 of Set 10 | praia da vitoria
# Processing Record 27 of Set 10 | merritt island
# Processing Record 28 of Set 10 | viitasaari
# Processing Record 29 of Set 10 | nago
# Processing Record 30 of Set 10 | vuktyl
# Processing Record 31 of Set 10 | saguenay
# Processing Record 32 of Set 10 | idiroko
# Processing Record 33 of Set 10 | akrehamn
# Processing Record 34 of Set 10 | makawao
# Processing Record 35 of Set 10 | ancud
# Processing Record 36 of Set 10 | kaitong
# Processing Record 37 of Set 10 | petrovsk
# Processing Record 38 of Set 10 | olyokminsk
# Processing Record 39 of Set 10 | mchinji
# Processing Record 40 of Set 10 | iskenderun
# Processing Record 41 of Set 10 | santa terezinha
# Processing Record 42 of Set 10 | veinticinco de mayo
# Processing Record 43 of Set 10 | jianshui
# Processing Record 44 of Set 10 | mirnyy
# Processing Record 45 of Set 10 | cartagena
# Processing Record 46 of Set 10 | olinda
# Processing Record 47 of Set 10 | guerrero negro
# Processing Record 48 of Set 10 | elbistan
# Processing Record 49 of Set 10 | thunder bay
# Processing Record 0 of Set 11 | ivins
# Processing Record 1 of Set 11 | sawakin
# Processing Record 2 of Set 11 | ivdel'
# Processing Record 3 of Set 11 | brokopondo
# Processing Record 4 of Set 11 | puerto aysen
# Processing Record 5 of Set 11 | colonia
# Processing Record 6 of Set 11 | cannonvale
# Processing Record 7 of Set 11 | sorong
# Processing Record 8 of Set 11 | westport
# Processing Record 9 of Set 11 | mendota
# Processing Record 10 of Set 11 | myanaung
# Processing Record 11 of Set 11 | rukban
# City not found. Skipping...
# Processing Record 12 of Set 11 | iskateley
# Processing Record 13 of Set 11 | tolanaro
# Processing Record 14 of Set 11 | lawrenceburg
# Processing Record 15 of Set 11 | kamen'-rybolov
# Processing Record 16 of Set 11 | poxoreo
# Processing Record 17 of Set 11 | doka
# Processing Record 18 of Set 11 | hirara
# Processing Record 19 of Set 11 | tabuk
# Processing Record 20 of Set 11 | yaren
# Processing Record 21 of Set 11 | huarmey
# Processing Record 22 of Set 11 | ar ruways
# Processing Record 23 of Set 11 | anandnagar
# Processing Record 24 of Set 11 | agat village
# Processing Record 25 of Set 11 | panarukan
# Processing Record 26 of Set 11 | san antonio de pale
# Processing Record 27 of Set 11 | kidal
# Processing Record 28 of Set 11 | luganville
# Processing Record 29 of Set 11 | broken hill
# Processing Record 30 of Set 11 | poronaysk
# Processing Record 31 of Set 11 | rokytne
# Processing Record 32 of Set 11 | makhambet
# Processing Record 33 of Set 11 | acarau
# Processing Record 34 of Set 11 | plastun
# Processing Record 35 of Set 11 | punto fijo
# Processing Record 36 of Set 11 | calvinia
# Processing Record 37 of Set 11 | al bardiyah
# Processing Record 38 of Set 11 | cockburn town
# Processing Record 39 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 40 of Set 11 | el alto
# Processing Record 41 of Set 11 | radaur
# Processing Record 42 of Set 11 | faya-largeau
# Processing Record 43 of Set 11 | sao miguel do araguaia
# Processing Record 44 of Set 11 | hamada
# Processing Record 45 of Set 11 | tongshan
# Processing Record 46 of Set 11 | antofagasta
# Processing Record 47 of Set 11 | san jose del guaviare
# Processing Record 48 of Set 11 | lepsy
# Processing Record 49 of Set 11 | oban
# Processing Record 0 of Set 12 | arish
# Processing Record 1 of Set 12 | essaouira
# Processing Record 2 of Set 12 | motygino
# Processing Record 3 of Set 12 | sanming
# Processing Record 4 of Set 12 | happy valley-goose bay
# Processing Record 5 of Set 12 | antsiranana
# Processing Record 6 of Set 12 | nantucket
# Processing Record 7 of Set 12 | richards bay
# Processing Record 8 of Set 12 | al fqih ben calah
# Processing Record 9 of Set 12 | hassi messaoud
# Processing Record 10 of Set 12 | carauari
# Processing Record 11 of Set 12 | saint-louis
# Processing Record 12 of Set 12 | new norfolk
# Processing Record 13 of Set 12 | aibak
# Processing Record 14 of Set 12 | santa vitoria do palmar
# Processing Record 15 of Set 12 | caras
# Processing Record 16 of Set 12 | dryden
# Processing Record 17 of Set 12 | worland
# Processing Record 18 of Set 12 | khalifah a city
# City not found. Skipping...
# Processing Record 19 of Set 12 | las tablas
# Processing Record 20 of Set 12 | shurugwi
# Processing Record 21 of Set 12 | tarawa
# Processing Record 22 of Set 12 | shipunovo
# Processing Record 23 of Set 12 | hajduszoboszlo
# Processing Record 24 of Set 12 | kharan
# Processing Record 25 of Set 12 | port douglas
# Processing Record 26 of Set 12 | rosarito
# Processing Record 27 of Set 12 | chinde
# Processing Record 28 of Set 12 | matadi
# Processing Record 29 of Set 12 | zheleznogorsk-ilimskiy
# Processing Record 30 of Set 12 | las heras
# Processing Record 31 of Set 12 | mhamid
# Processing Record 32 of Set 12 | watertown
# Processing Record 33 of Set 12 | gadzhiyevo
# Processing Record 34 of Set 12 | babati
# Processing Record 35 of Set 12 | espargos
# City not found. Skipping...
# Processing Record 36 of Set 12 | xochitlan todos santos
# Processing Record 37 of Set 12 | sitka
# Processing Record 38 of Set 12 | hemmoor
# Processing Record 39 of Set 12 | charlotte amalie
# Processing Record 40 of Set 12 | athagarh
# Processing Record 41 of Set 12 | el reno
# Processing Record 42 of Set 12 | protaras
# Processing Record 43 of Set 12 | bengkulu
# Processing Record 44 of Set 12 | jaito
# Processing Record 45 of Set 12 | yomju-up
# Processing Record 46 of Set 12 | neijiang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          566
# Lat           566
# Lng           566
# Max Temp      566
# Humidity      566
# Cloudiness    566
# Wind Speed    566
# Country       566
# Date          566
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto natales -51.7236  -72.4875      4.82        69          10
# 1       adamstown -25.0660 -130.1015     18.04        82         100
# 2      swakopmund -22.6833   14.5333     13.47        81           0
# 3          hasaki  35.7333  140.8333     25.22        89         100
# 4           alofi -19.0595 -169.9187     23.94        64          75
#
#    Wind Speed Country        Date
# 0        3.59      CL  1694810684
# 1       12.13      PN  1694810685
# 2        5.04      NA  1694810719
# 3        1.53      JP  1694810691
# 4        5.14      NU  1694810685

# %%
# Export the City_Data into a csv
city_data_df.to_csv("../output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("../output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto natales -51.7236  -72.4875      4.82        69          10
# 1             adamstown -25.0660 -130.1015     18.04        82         100
# 2            swakopmund -22.6833   14.5333     13.47        81           0
# 3                hasaki  35.7333  140.8333     25.22        89         100
# 4                 alofi -19.0595 -169.9187     23.94        64          75
#
#          Wind Speed Country        Date
# City_ID
# 0              3.59      CL  1694810684
# 1             12.13      PN  1694810685
# 2              5.04     NaN  1694810719
# 3              1.53      JP  1694810691
# 4              5.14      NU  1694810685

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]
plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitude vs. Maximum Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]
plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity %")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]
plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]
plt.scatter(x_values, y_values, marker="o", facecolors="blue", edgecolors="black", alpha=0.75)

# Incorporate the other graph properties
plt.title("Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed m/s")
plt.grid()

# Save the figure
plt.savefig("../output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 3            hasaki  35.7333  140.8333     25.22        89         100
# 10             nuuk  64.1835  -51.7216      3.34       100          75
# 11            lihue  21.9789 -159.3672     30.58        68          20
# 13        stornoway  58.2093   -6.3865      8.38        79          40
# 14       anar darah  32.7587   61.6540     21.59        28           0
#
#          Wind Speed Country        Date
# City_ID
# 3              1.53      JP  1694810691
# 10             3.60      GL  1694810699
# 11             5.14      US  1694810709
# 13             1.54      GB  1694810720
# 14             5.18      AF  1694810720

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        puerto natales -51.7236  -72.4875      4.82        69          10
# 1             adamstown -25.0660 -130.1015     18.04        82         100
# 2            swakopmund -22.6833   14.5333     13.47        81           0
# 4                 alofi -19.0595 -169.9187     23.94        64          75
# 5             hithadhoo  -0.6000   73.0833     28.17        76          14
#
#          Wind Speed Country        Date
# City_ID
# 0              3.59      CL  1694810684
# 1             12.13      PN  1694810685
# 2              5.04     NaN  1694810719
# 4              5.14      NU  1694810685
# 5              5.82      MV  1694810707

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df ['Lat']
y_values = northern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (C)')
plt.show()
print(f'The r-squared value is: {rvalue**2}.')
x_values.count()
# Out:
# The r-squared value is: 0.6458467541959055.
# 389

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df ['Lat']
y_values = southern_hemi_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (C)')
plt.show()
print(f'The r-squared value is: {rvalue**2}.')
x_values.count()
# Out:
# The r-squared value is: 0.5593628058201023.
# 177

# %% [markdown]
# **Discussion about the linear relationship:** The r-squared value is lower in the southern hemisphere than the northern hemisphere. In both representations, it is clear that as the latitude approaches the equator (lat = 0), the maximum temperature increases. However, the data is more dispersed in the southern hemisphere than the north. This could be a skewed graph because based on the number of data points, it appears that the northern hemisphere has more points than the southern hemisphere graph, so this has to be taken into account, because a larger sample size will provide more representative data than a small sample size. This is confirmed by the number of counts - 389 in the northern hemisphere vs 177 in the southern hemisphere. We cannot simply just look at the r-squared value without looking at the dispersion of data points either. In this case, as the r-squared value is greated in the northern hemisphere, we can confirm that the dependent variable (temperature) is highly linked to the positon of the latitude, as the data is also far less dispersed in the northern hemisphere. In the southern hemisphere, the data is more dispersed, suggesting that if I was to predict the max temperature for a latitude based on the regression line, the margin of error is likely to be greater.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ['Lat']
y_values = northern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()
print(f'The r-squared value is: {rvalue**2}.')
# Out:
# The r-squared value is: 0.0008214828694432685.

# %%
# Southern Hemisphere
x_values = southern_hemi_df ['Lat']
y_values = southern_hemi_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
plt.show()
formatted_r_squared = '{:.15f}'.format(rvalue**2)
print(f'The r-squared value is: {formatted_r_squared}.')
# Out:
# The r-squared value is: 0.000009089605178.

# %% [markdown]
# **Discussion about the linear relationship:** The r-squared values for our dependent variable, humidity vs. the latitude is basically close to 0, which suggests that there is no relationship between the humidity vs the latitude of cities across the world. You can also see this quite clearly with the dispersion of the data, and the slope of the line, which is essentially horizontal. This suggests that there is almost no relationship between humidity and latitude, suggesting that another factor must be responsible which humidity is dependent on. Further analysis would be required here, against another independent variable. There is only a mild relationship between latitude and humidity in the northern hemisphere, but this is not enough to show a significant correlation between the two.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ['Lat']
y_values = northern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()
print(f'The r-squared value is: {rvalue**2}.')
# Out:
# The r-squared value is: 9.325096212010757e-06.

# %%
# Southern Hemisphere
x_values = southern_hemi_df ['Lat']
y_values = southern_hemi_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
plt.show()
print(f'The r-squared value is: {rvalue**2}.')
# Out:
# The r-squared value is: 0.001470622291276004.

# %% [markdown]
# **Discussion about the linear relationship:** The r-squared values for our dependent variable, cloudiness vs. the latitude is basically close to 0, which suggests that there is no relationship between the cloudiness vs the latitude of cities across the world. You can also see this quite clearly with the dispersion of the data, and the slope of the line, which is essentially horizontal. This suggests that there is almost no relationship between cloudiness and latitude, suggesting that another factor must be responsible which cloudiness is dependent on. Further analysis would be required here, against another independent variable. There is only an extremely mild negative relationship between cloudiness and latitude, but once again, this is not enough to make a generalised comment on the correlation between the two. The southern hemisphere data shows that majority of latitude points plotted are closer to the equator than not, in the southern chart, and in the northern chart, the cloudiness is more spread out.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df ['Lat']
y_values = northern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.show()
formatted_r_squared = '{:.15f}'.format(rvalue**2)
print(f'The r-squared value is: {formatted_r_squared}.')
# Out:
# The r-squared value is: 0.000097224352455.

# %%
# Southern Hemisphere
x_values = southern_hemi_df ['Lat']
y_values = southern_hemi_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5.8,0.8),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.show()
print(f'The r-squared value is: {rvalue**2}.')
# Out:
# The r-squared value is: 0.055133033278687495.

# %% [markdown]
# **Discussion about the linear relationship:** The r-squared values for our dependent variable, wind speed vs. the latitude is basically close to 0, which suggests that there is no relationship between the humidity vs the latitude of cities across the world irregardless of region of hemisphere. You can also see this quite clearly with the dispersion of the data, and the slope of the line, which is essentially horizontal for the northern hemisphere. This suggests that there is almost no relationship between humidity and latitude there, suggesting that another factor must be responsible which wind speed is dependent on. In the southern hemisphere however, this is slightly more data closer to the regression line, particularly as we look at wind speed closer to the equator. This suggests that there is a small possibility that the latitude is what impacts wind speed, but the r-squared value is still not significant enough for us to make this a definitive assumption unless other independent variables are also studied.
