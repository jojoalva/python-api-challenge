# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0  puerto natales -51.7236  -72.4875      4.82        69          10
# 1        1       adamstown -25.0660 -130.1015     18.04        82         100
# 2        2      swakopmund -22.6833   14.5333     13.47        81           0
# 3        3          hasaki  35.7333  140.8333     25.22        89         100
# 4        4           alofi -19.0595 -169.9187     23.94        64          75
#
#    Wind Speed Country        Date
# 0        3.59      CL  1694810684
# 1       12.13      PN  1694810685
# 2        5.04     NaN  1694810719
# 3        1.53      JP  1694810691
# 4        5.14      NU  1694810685

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 700,
    frame_height = 500,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha=0.5
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity)

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
new_df = city_data_df[(city_data_df["Max Temp"] > 21) & (city_data_df["Max Temp"] < 27) & (city_data_df["Wind Speed"] < 4.5) & (city_data_df["Cloudiness"] == 0)]

# Drop any rows with null values
new_df = new_df.dropna(how='any')

# Display sample data
new_df
# Out:
#      City_ID             City      Lat       Lng  Max Temp  Humidity  \
# 71        71          awjilah  29.1081   21.2869     26.12        25
# 86        86          zambezi -13.5432   23.1047     21.23        28
# 186      186         hamilton  39.1834  -84.5333     26.23        44
# 195      195       letlhakane -21.4167   25.5833     22.11        24
# 200      200           rakops -21.0167   24.3333     22.35        24
# 214      214         malaunay  49.5271    1.0429     21.31        63
# 218      218       miles city  46.4083 -105.8406     23.54        25
# 227      227          tsiombe -25.3000   45.4833     22.28        64
# 240      240        jamestown  42.0970  -79.2353     21.40        50
# 283      283  castel volturno  41.0149   13.9462     24.46        88
# 301      301          toliara -23.3500   43.6667     22.43        76
# 309      309       ponta pora -22.5361  -55.7256     25.95        25
# 372      372         jamalpur  24.9167   89.9333     26.44        89
# 386      386             elko  41.0002 -115.5012     25.64        20
# 396      396          weirton  40.4190  -80.5895     24.49        37
# 407      407           marion  39.7684  -86.1555     26.34        41
# 420      420          mulanje -16.0316   35.5000     23.01        48
# 463      463       iskenderun  36.5872   36.1735     24.46        58
# 486      486     lawrenceburg  38.0373  -84.8966     26.53        41
# 521      521            arish  31.1316   33.7984     26.17        58
# 538      538          worland  44.0169 -107.9554     25.64        29
# 561      561         protaras  35.0125   34.0583     26.10        66
#
#      Cloudiness  Wind Speed Country        Date
# 71            0        3.26      LY  1694810689
# 86            0        2.58      ZM  1694810726
# 186           0        3.09      US  1694810007
# 195           0        2.63      BW  1694810736
# 200           0        2.45      BW  1694810736
# 214           0        4.12      FR  1694810737
# 218           0        3.09      US  1694810738
# 227           0        1.77      MG  1694810738
# 240           0        2.24      US  1694810424
# 283           0        1.54      IT  1694810743
# 301           0        1.91      MG  1694810745
# 309           0        2.06      BR  1694810746
# 372           0        2.38      BD  1694810751
# 386           0        3.58      US  1694810753
# 396           0        1.34      US  1694810564
# 407           0        4.12      US  1694809941
# 420           0        2.37      MW  1694810756
# 463           0        1.68      TR  1694810760
# 486           0        3.09      US  1694810762
# 521           0        2.72      EG  1694810766
# 538           0        3.09      US  1694810767
# 561           0        0.45      CY  1694810770

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df = new_df[["City", "Country", "Lat", "Lng", "Humidity"]].copy()

# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
hotel_df["Hotel Name"] = ''

# Display sample data
hotel_df
# Out:
#                 City Country      Lat       Lng  Humidity Hotel Name
# 71           awjilah      LY  29.1081   21.2869        25
# 86           zambezi      ZM -13.5432   23.1047        28
# 186         hamilton      US  39.1834  -84.5333        44
# 195       letlhakane      BW -21.4167   25.5833        24
# 200           rakops      BW -21.0167   24.3333        24
# 214         malaunay      FR  49.5271    1.0429        63
# 218       miles city      US  46.4083 -105.8406        25
# 227          tsiombe      MG -25.3000   45.4833        64
# 240        jamestown      US  42.0970  -79.2353        50
# 283  castel volturno      IT  41.0149   13.9462        88
# 301          toliara      MG -23.3500   43.6667        76
# 309       ponta pora      BR -22.5361  -55.7256        25
# 372         jamalpur      BD  24.9167   89.9333        89
# 386             elko      US  41.0002 -115.5012        20
# 396          weirton      US  40.4190  -80.5895        37
# 407           marion      US  39.7684  -86.1555        41
# 420          mulanje      MW -16.0316   35.5000        48
# 463       iskenderun      TR  36.5872   36.1735        58
# 486     lawrenceburg      US  38.0373  -84.8966        41
# 521            arish      EG  31.1316   33.7984        58
# 538          worland      US  44.0169 -107.9554        29
# 561         protaras      CY  35.0125   34.0583        66

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 10000

params = {
    "categories":"accommodation.hotel",
    "apiKey":geoapify_key,
    "limit":20,
    "filter":{},
    "bias":{},
    "apiKey":geoapify_key
}

# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    
    # get latitude, longitude from the DataFrame
    latitude= row["Lat"]
    longitude= row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{longitude},{latitude},{radius}"
    params["bias"] = f"proximity:{longitude},{latitude}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = requests.get(base_url, params=params)
    
    # Convert the API response to JSON format
    name_address = name_address.json()
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# awjilah - nearest hotel: No hotel found
# zambezi - nearest hotel: No hotel found
# hamilton - nearest hotel: North Vista Manor
# letlhakane - nearest hotel: Boteti Hotel
# rakops - nearest hotel: Rakops River Lodge
# malaunay - nearest hotel: Campanile
# miles city - nearest hotel: Historic Olive Hotel
# tsiombe - nearest hotel: No hotel found
# jamestown - nearest hotel: DoubleTree Jamestown
# castel volturno - nearest hotel: Hotel Al Buschetto
# toliara - nearest hotel: Ambary
# ponta pora - nearest hotel: Pousada do Bosque
# jamalpur - nearest hotel: Hotel Star International
# elko - nearest hotel: No hotel found
# weirton - nearest hotel: Holiday Inn
# marion - nearest hotel: Hilton Garden Inn Indianapolis Downtown
# mulanje - nearest hotel: No hotel found
# iskenderun - nearest hotel: aykut palace
# lawrenceburg - nearest hotel: No hotel found
# arish - nearest hotel: سينا
# worland - nearest hotel: Town House Motor Inn
# protaras - nearest hotel: Capo Bay
#                 City Country      Lat       Lng  Humidity  \
# 71           awjilah      LY  29.1081   21.2869        25
# 86           zambezi      ZM -13.5432   23.1047        28
# 186         hamilton      US  39.1834  -84.5333        44
# 195       letlhakane      BW -21.4167   25.5833        24
# 200           rakops      BW -21.0167   24.3333        24
# 214         malaunay      FR  49.5271    1.0429        63
# 218       miles city      US  46.4083 -105.8406        25
# 227          tsiombe      MG -25.3000   45.4833        64
# 240        jamestown      US  42.0970  -79.2353        50
# 283  castel volturno      IT  41.0149   13.9462        88
# 301          toliara      MG -23.3500   43.6667        76
# 309       ponta pora      BR -22.5361  -55.7256        25
# 372         jamalpur      BD  24.9167   89.9333        89
# 386             elko      US  41.0002 -115.5012        20
# 396          weirton      US  40.4190  -80.5895        37
# 407           marion      US  39.7684  -86.1555        41
# 420          mulanje      MW -16.0316   35.5000        48
# 463       iskenderun      TR  36.5872   36.1735        58
# 486     lawrenceburg      US  38.0373  -84.8966        41
# 521            arish      EG  31.1316   33.7984        58
# 538          worland      US  44.0169 -107.9554        29
# 561         protaras      CY  35.0125   34.0583        66
#
#                                   Hotel Name
# 71                            No hotel found
# 86                            No hotel found
# 186                        North Vista Manor
# 195                             Boteti Hotel
# 200                       Rakops River Lodge
# 214                                Campanile
# 218                     Historic Olive Hotel
# 227                           No hotel found
# 240                     DoubleTree Jamestown
# 283                       Hotel Al Buschetto
# 301                                   Ambary
# 309                        Pousada do Bosque
# 372                 Hotel Star International
# 386                           No hotel found
# 396                              Holiday Inn
# 407  Hilton Garden Inn Indianapolis Downtown
# 420                           No hotel found
# 463                             aykut palace
# 486                           No hotel found
# 521                                     سينا
# 538                     Town House Motor Inn
# 561                                 Capo Bay

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_2 = hotel_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM",
    frame_width = 800,
    frame_height = 600,
    size = "Humidity",
    scale = 1,
    color = "City",
    alpha=0.5,
    hover_cols=['Country', 'Hotel Name']
)

    
# Display the map
map_plot_2
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]   (City,Humidity,Country,Hotel Name)
